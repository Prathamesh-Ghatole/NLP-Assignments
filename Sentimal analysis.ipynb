# %%
from textblob import TextBlob
import nltk
from textblob.sentiments import NaiveBayesAnalyzer, PatternAnalyzer

# %%
text = 'Apple is a very succcessful company due to its visionary leadership team. They have a very bright future'

# %%
blob = TextBlob(text)
blob.sentiment
# Out:
# Sentiment(polarity=0.24625000000000002, subjectivity=0.45)

# %%
import nltk
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())
blob.sentiment
# Out:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/textblob/decorators.py in decorated(*args, **kwargs)
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#
# /usr/local/lib/python3.8/dist-packages/textblob/tokenizers.py in tokenize(self, text)
#      56         '''Return a list of sentences.'''
# ---> 57         return nltk.tokenize.sent_tokenize(text)
#      58
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in _open(resource_url)
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# MissingCorpusError                        Traceback (most recent call last)
# <ipython-input-8-4c536ef30f57> in <module>
#       1 blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())
# ----> 2 blob.sentiment
#
# /usr/local/lib/python3.8/dist-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /usr/local/lib/python3.8/dist-packages/textblob/blob.py in sentiment(self)
#     430         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     431         """
# --> 432         return self.analyzer.analyze(self.raw)
#     433
#     434     @cached_property
#
# /usr/local/lib/python3.8/dist-packages/textblob/en/sentiments.py in analyze(self, text)
#      87         # Lazily train the classifier
#      88         super(NaiveBayesAnalyzer, self).analyze(text)
# ---> 89         tokens = word_tokenize(text, include_punc=False)
#      90         filtered = (t.lower() for t in tokens if len(t) >= 3)
#      91         feats = self.feature_extractor(filtered)
#
# /usr/local/lib/python3.8/dist-packages/textblob/tokenizers.py in word_tokenize(text, include_punc, *args, **kwargs)
#      71         _word_tokenizer.itokenize(sentence, include_punc=include_punc,
#      72                                 *args, **kwargs)
# ---> 73         for sentence in sent_tokenize(text))
#      74     return words
#
# /usr/local/lib/python3.8/dist-packages/textblob/base.py in itokenize(self, text, *args, **kwargs)
#      62         :rtype: generator
#      63         """
# ---> 64         return (t for t in self.tokenize(text, *args, **kwargs))
#      65
#      66 ##### SENTIMENT ANALYZERS ####
#
# /usr/local/lib/python3.8/dist-packages/textblob/decorators.py in decorated(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
# ---> 38             raise MissingCorpusError()
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True
